# %%
from os import PathLike
from hdfs import InsecureClient
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from pyspark.sql.functions import *
from pyspark.sql.types import LongType, StringType, StructField, StructType, BooleanType, ArrayType, IntegerType,FloatType

warehouse_location = 'hdfs://hdfs-nn:9870/TrabalhoPL'

builder = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark DataFrames and SQL") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/TrabalhoPL/bronze/spill-incidents.csv"

customSchema = StructType([
    StructField("Spill Number", StringType(), True),        
    StructField("Program Facility Name", StringType(), True),
    StructField("Street 1", StringType(), True),
    StructField("Street 2", StringType(), True),
    StructField("Locality", StringType(), True),
    StructField("Contry", StringType(), True),
    StructField("ZIP Code", StringType(), True),
    StructField("SWIS Code", IntegerType(), True), 
    StructField("DEC Region", IntegerType(), True),  
    StructField("Spill Date", StringType(), True),
    StructField("Received Date", StringType(), True), 
    StructField("Contributing Factor", StringType(), True),
    StructField("Waterbody", StringType(), True),
    StructField("Source", StringType(), True),
    StructField("Close Date", StringType(), True),
    StructField("Material Name", StringType(), True),
    StructField("Material Family", StringType(), True),
    StructField("Quantity", FloatType(), True),
    StructField("Units", StringType(), True),
    StructField("Recovered", FloatType(), True)
    
])

projeto_spill = spark \
            .read\
            .option("delimiter",",")\
            .option("header","true")\
            .schema(customSchema) \
            .csv(hdfs_path)
projeto_spill.show()
# Out:
# +------------+---------------------+--------------------+--------+----------------+-----------+--------+---------+----------+--------------------+--------------------+-------------------+----------+--------------------+--------------------+------------------+---------------+--------+-------+---------+
# |Spill Number|Program Facility Name|            Street 1|Street 2|        Locality|     Contry|ZIP Code|SWIS Code|DEC Region|          Spill Date|       Received Date|Contributing Factor| Waterbody|              Source|          Close Date|     Material Name|Material Family|Quantity|  Units|Recovered|
# +------------+---------------------+--------------------+--------+----------------+-----------+--------+---------+----------+--------------------+--------------------+-------------------+----------+--------------------+--------------------+------------------+---------------+--------+-------+---------+
# |    0107132 |    MH 864        ...|  RT 119/MILLWOOD RD|    null|        ELMSFORD|Westchester|    null|     6000|         3|2001-10-10T00:00:...|2001-10-10T00:00:...|            Unknown|      null|             Unknown|2001-10-15T00:00:...|  unknown material|          Other|    10.0|Gallons|      0.0|
# |    0405586 |   BOWRY BAY      ...|  WATER POLL CONTROL|    null|          QUEENS|     Queens|    null|     4101|         2|2004-08-21T00:00:...|2004-08-21T00:00:...|              Other|EAST RIVER|             Unknown|2004-09-17T00:00:...|        raw sewage|          Other|     0.0| Pounds|      0.0|
# |    0405586 |   BOWRY BAY      ...|  WATER POLL CONTROL|    null|          QUEENS|     Queens|    null|     4101|         2|2004-08-21T00:00:...|2004-08-21T00:00:...|              Other|EAST RIVER|             Unknown|2004-09-17T00:00:...|        raw sewage|          Other|     0.0|   null|      0.0|
# |    0204667 |   POLE 16091     ...| GRACE AVE/BURKE AVE|    null|           BRONX|      Bronx|    null|      301|         2|2002-08-02T00:00:...|2002-08-02T00:00:...|  Equipment Failure|      null|Commercial/Indust...|2002-10-28T00:00:...|   transformer oil|      Petroleum|     1.0|Gallons|      0.0|
# |    0210559 |   POLE ON        ...|FERDALE LOMIS RD ...|    null|         LIBERTY|   Sullivan|    null|     5336|         3|2003-01-20T00:00:...|2003-01-20T00:00:...|   Traffic Accident|      null|Commercial/Indust...|2003-01-22T00:00:...|   transformer oil|      Petroleum|     6.0|Gallons|      6.0|
# |    0311484 |   PRIVATE RESIDEN...|  6568 GLEN HAVEN RD|    null|           SCOTT|   Cortland|    null|     1238|         7|2004-01-11T00:00:...|2004-01-11T00:00:...|  Equipment Failure|      null|    Private Dwelling|2004-08-25T00:00:...|       #2 fuel oil|      Petroleum|    75.0|Gallons|      0.0|
# |    0104307 |  149TH RD        ...|183RD ST, 149TH A...|    null|          QUEENS|     Queens|    null|     4101|         2|2001-07-23T00:00:...|2001-07-23T00:00:...|    Abandoned Drums|      null|             Unknown|2001-08-01T00:00:...|  unknown material|          Other|     0.0|Gallons|      0.0|
# |    0160046 |  ABANDONED DRUMS ...|BAKER SCHOOL HOUS...|    null|           SOLON|   Cortland|    null|     1200|         7|2001-11-23T00:00:...|2001-11-23T00:00:...|    Abandoned Drums|      null|             Unknown|2002-05-14T00:00:...|  unknown material|          Other|     0.0|Gallons|      0.0|
# |    9606869 |  AMSTERDAM AVE   ...|   WEST 79 TH STREET|    null|             NYC|   New York|    null|     3101|         2|1996-08-28T00:00:...|1996-08-28T00:00:...|   Traffic Accident|      null|  Commercial Vehicle|1996-08-29T00:00:...|        antifreeze|          Other|     2.0|Gallons|      2.0|
# |    0312198 |  APARTMENT BUILDI...|4 SOUTH SIDE TERR...|    null|       NEW PALTZ|     Ulster|    null|     5638|         3|2004-02-02T00:00:...|2004-02-02T00:00:...|       Tank Failure|      null|Commercial/Indust...|2004-04-05T00:00:...|       #2 fuel oil|      Petroleum|     0.0| Pounds|      0.0|
# |    0109039 |  APT BUILDING    ...|      94-06  34TH RD|    null|          QUEENS|     Queens|    null|     4101|         2|2001-12-11T00:00:...|2001-12-11T00:00:...|  Equipment Failure|      null|          Tank Truck|2001-12-21T00:00:...|       #2 fuel oil|      Petroleum|     5.0|Gallons|      5.0|
# |    0312848 |  BROOKLYN TECH HI...| 29 FORT GREEN PLACE|    null|        BROOKLYN|      Kings|    null|     2401|         2|2004-02-20T00:00:...|2004-02-20T00:00:...|        Human Error|      null|Institutional, Ed...|2004-02-27T00:00:...|       #6 fuel oil|      Petroleum|    10.0|Gallons|      0.0|
# |    0260048 |  CRAINS MILL ROAD...|    CRAINS MILL ROAD|    null|         TRUXTON|   Cortland|    null|     1244|         7|2002-10-16T00:00:...|2002-10-16T00:00:...|         Deliberate|      null|             Unknown|2002-10-20T00:00:...|  unknown material|          Other|     0.0|Gallons|      0.0|
# |    0400907 |  CSX RAILYARD    ...|      644 ULSTER AVE|    null|        KINGSTON|     Ulster|    null|     5630|         3|2004-04-27T00:00:...|2004-04-27T00:00:...|  Equipment Failure|      null|        Railroad Car|2004-04-27T00:00:...|          lube oil|      Petroleum|    10.0|Gallons|      0.0|
# |    0304214 |  CULL RESIDENCE  ...|         88 FARAH LN|    null|      MIDDLETOWN|     Orange|    null|     3609|         3|2003-07-22T00:00:...|2003-07-22T00:00:...|         Deliberate|      null|    Private Dwelling|2003-07-30T00:00:...|       #2 fuel oil|      Petroleum|     0.0|Gallons|      0.0|
# |    0008342 |  GREER TOYOTA    ...|           1420 RT 9|    null|WAPPINGERS FALLS|   Dutchess|    null|     1400|         3|2000-10-12T00:00:...|2000-10-17T00:00:...|       Tank Failure|      null|Commercial/Indust...|2000-10-17T00:00:...|waste oil/used oil|      Petroleum|     0.0|Gallons|      0.0|
# |    0405793 |  MANHOLE #58430  ...| W 59TH ST / 12TH AV|    null|       MANHATTAN|   New York|    null|     3101|         2|2004-08-26T00:00:...|2004-08-26T00:00:...|            Unknown|      null|             Unknown|2006-10-23T00:00:...| unknown petroleum|      Petroleum|     1.0|   null|      0.0|
# |    0405793 |  MANHOLE #58430  ...| W 59TH ST / 12TH AV|    null|       MANHATTAN|   New York|    null|     3101|         2|2004-08-26T00:00:...|2004-08-26T00:00:...|            Unknown|      null|             Unknown|2006-10-23T00:00:...| unknown petroleum|      Petroleum|     1.0| Pounds|      0.0|
# |    0313032 |  MANHOLE #6014   ...|156-170 WEST 42ND...|    null|       MANHATTAN|   New York|    null|     3101|         2|2004-02-26T00:00:...|2004-02-26T00:00:...|            Unknown|      null|             Unknown|2004-07-15T00:00:...| unknown petroleum|      Petroleum|     2.0|Gallons|      0.0|
# |    9814599 |  MANHOLE 2981    ...|CLASSON AVE & FUL...|    null|        BROOKLYN|      Kings|    null|     2401|         2|1999-03-08T00:00:...|1999-03-08T00:00:...|            Unknown|      null|             Unknown|1999-03-22T00:00:...| unknown petroleum|      Petroleum|     4.0|Gallons|      0.0|
# +------------+---------------------+--------------------+--------+----------------+-----------+--------+---------+----------+--------------------+--------------------+-------------------+----------+--------------------+--------------------+------------------+---------------+--------+-------+---------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import when, col, concat, lit

replaced_projeto_spill = projeto_spill.withColumn(
    "Spill Date",
    when(
        (col("Spill Date").isNull() | (col("Spill Date") == None)), 
        "0000-00-00T00:00:00.000"
    ).otherwise(col("Spill Date")))

# %%
replaced_projeto_spill2 = replaced_projeto_spill.withColumn(
    "Received Date",
    when(
        (col("Received Date").isNull() | (col("Received Date") == None)), 
        "0000-00-00T00:00:00.000"
    ).otherwise(col("Received Date")))

# %%
replaced_projeto_spill3 = replaced_projeto_spill2.withColumn(
    "Close Date",
    when(
        (col("Close Date").isNull() | (col("Close Date") == None)), 
        "0000-00-00T00:00:00.000"
    ).otherwise(col("Close Date")))

# %%
replaced_projeto_spill4 = replaced_projeto_spill3.withColumn('Data_Derrame', split(replaced_projeto_spill3['Spill Date'], 'T').getItem(0)) \
                                                .withColumn('Data_Relatada', split(replaced_projeto_spill3['Received Date'], 'T').getItem(0)) \
                                                .withColumn('Data_Fim', split(replaced_projeto_spill3['Close Date'], 'T').getItem(0)) \
                                                .drop(col("Spill Date")) \
                                                .drop(col("Received Date")) \
                                                .drop(col("Close Date")) \
                                                .drop(col("Street 2")) \
                                                .drop(col("ZIP Code"))
replaced_projeto_spill4.toPandas()
# Out:
#        Spill Number      Program Facility Name                   Street 1  \
# 0          0107132      MH 864                         RT 119/MILLWOOD RD
# 1          0405586     BOWRY BAY                       WATER POLL CONTROL
# 2          0405586     BOWRY BAY                       WATER POLL CONTROL
# 3          0204667     POLE 16091                     GRACE AVE/BURKE AVE
# 4          0210559     POLE ON                   FERDALE LOMIS RD / RT 52
# ...             ...                        ...                        ...
# 499052     9904003                      `-NYCT         5TH AND WEST 50 ST
# 499053     0304463                      `-NYCT       35TH ST AND 11TH AVE
# 499054     9213322             `-NYCT / 146 ST              721 LENOX AVE
# 499055     8909580      `-NYCT BUS DEPOT - S I  CASTLETON AVE @ RECTOR ST
# 499056     0102768                `-RAVENSWOOD            3854 VERON BLVD
#
#                 Locality       Contry  SWIS Code  DEC Region  \
# 0               ELMSFORD  Westchester       6000           3
# 1                 QUEENS       Queens       4101           2
# 2                 QUEENS       Queens       4101           2
# 3                  BRONX        Bronx        301           2
# 4                LIBERTY     Sullivan       5336           3
# ...                  ...          ...        ...         ...
# 499052         MANHATTAN     New York       3101           2
# 499053         MANHATTAN     New York       3101           2
# 499054         MANHATTAN     New York       3101           2
# 499055     STATEN ISLAND     Richmond       4301           2
# 499056  LONG ISLAND CITY       Queens       4101           2
#
#        Contributing Factor   Waterbody                 Source  \
# 0                  Unknown        None                Unknown
# 1                    Other  EAST RIVER                Unknown
# 2                    Other  EAST RIVER                Unknown
# 3        Equipment Failure        None  Commercial/Industrial
# 4         Traffic Accident        None  Commercial/Industrial
# ...                    ...         ...                    ...
# 499052        Housekeeping        None     Commercial Vehicle
# 499053             Unknown        None                Unknown
# 499054       Tank Overfill        None  Commercial/Industrial
# 499055     Abandoned Drums        None  Commercial/Industrial
# 499056             Unknown  EAST RIVER                Unknown
#
#             Material Name Material Family  Quantity    Units  Recovered  \
# 0        unknown material           Other      10.0  Gallons        0.0
# 1              raw sewage           Other       0.0   Pounds        0.0
# 2              raw sewage           Other       0.0     None        0.0
# 3         transformer oil       Petroleum       1.0  Gallons        0.0
# 4         transformer oil       Petroleum       6.0  Gallons        6.0
# ...                   ...             ...       ...      ...        ...
# 499052             diesel       Petroleum      20.0  Gallons        0.0
# 499053  unknown petroleum       Petroleum       0.0  Gallons        0.0
# 499054        #2 fuel oil       Petroleum     200.0  Gallons        0.0
# 499055  unknown petroleum       Petroleum       0.0     None        0.0
# 499056  unknown petroleum       Petroleum       0.0  Gallons        0.0
#
#        Data_Derrame Data_Relatada    Data_Fim
# 0        2001-10-10    2001-10-10  2001-10-15
# 1        2004-08-21    2004-08-21  2004-09-17
# 2        2004-08-21    2004-08-21  2004-09-17
# 3        2002-08-02    2002-08-02  2002-10-28
# 4        2003-01-20    2003-01-20  2003-01-22
# ...             ...           ...         ...
# 499052   1999-07-06    1999-07-06  2009-03-03
# 499053   2003-07-28    2003-07-28  2014-01-08
# 499054   1993-03-02    1993-03-02  2003-02-10
# 499055   1990-01-05    1990-01-05  1990-01-05
# 499056   2001-06-13    2001-06-13  2013-05-07
#
# [499057 rows x 18 columns]

# %%
replaced_projeto_spill4 = replaced_projeto_spill4.withColumn(
    "Street 1",
    when(
        (col("Street 1").isNull() | (col("Street 1") == None)), 
        "Desconhecida"
    ).otherwise(col("Street 1")))

# %%
replaced_projeto_spill4 = replaced_projeto_spill4.withColumn(
    "Locality",
    when(
        (col("Locality").isNull() | (col("Locality") == None)), 
        "Desconhecida"
    ).otherwise(col("Locality")))

# %%
replaced_projeto_spill4 = replaced_projeto_spill4.withColumn(
    "Waterbody",
    when(
        (col("Waterbody").isNull() | (col("Waterbody") == None)), 
        "Nenhuma"
    ).otherwise(col("Waterbody")))

# %%
replaced_projeto_spill4 = replaced_projeto_spill4.withColumn(
    "Units",
    when(
        (col("Units").isNull() | (col("Units") == None)), 
        "Desconhecida"
    ).otherwise(col("Units")))

# %%
replaced_projeto_spill5 = replaced_projeto_spill4.withColumn(
    "DEC Region",
    when(
        ((col("DEC Region") == 1) | (col("DEC Region") == 3) | (col("DEC Region") == 4) | (col("DEC Region") == 5) | (col("DEC Region") == 6) | (col("DEC Region") == 8)), 
        None
    ).otherwise(col("DEC Region")))

replaced_projeto_spill6 = replaced_projeto_spill5.na.drop()
replaced_projeto_spill6.toPandas()
# Out:
#        Spill Number      Program Facility Name                   Street 1  \
# 0          0405586     BOWRY BAY                       WATER POLL CONTROL
# 1          0405586     BOWRY BAY                       WATER POLL CONTROL
# 2          0204667     POLE 16091                     GRACE AVE/BURKE AVE
# 3          0311484     PRIVATE RESIDENCE               6568 GLEN HAVEN RD
# 4          0104307    149TH RD                  183RD ST, 149TH AV& 149RD
# ...             ...                        ...                        ...
# 168047     9904003                      `-NYCT         5TH AND WEST 50 ST
# 168048     0304463                      `-NYCT       35TH ST AND 11TH AVE
# 168049     9213322             `-NYCT / 146 ST              721 LENOX AVE
# 168050     8909580      `-NYCT BUS DEPOT - S I  CASTLETON AVE @ RECTOR ST
# 168051     0102768                `-RAVENSWOOD            3854 VERON BLVD
#
#                 Locality    Contry  SWIS Code  DEC Region Contributing Factor  \
# 0                 QUEENS    Queens       4101           2               Other
# 1                 QUEENS    Queens       4101           2               Other
# 2                  BRONX     Bronx        301           2   Equipment Failure
# 3                  SCOTT  Cortland       1238           7   Equipment Failure
# 4                 QUEENS    Queens       4101           2     Abandoned Drums
# ...                  ...       ...        ...         ...                 ...
# 168047         MANHATTAN  New York       3101           2        Housekeeping
# 168048         MANHATTAN  New York       3101           2             Unknown
# 168049         MANHATTAN  New York       3101           2       Tank Overfill
# 168050     STATEN ISLAND  Richmond       4301           2     Abandoned Drums
# 168051  LONG ISLAND CITY    Queens       4101           2             Unknown
#
#          Waterbody                 Source      Material Name Material Family  \
# 0       EAST RIVER                Unknown         raw sewage           Other
# 1       EAST RIVER                Unknown         raw sewage           Other
# 2          Nenhuma  Commercial/Industrial    transformer oil       Petroleum
# 3          Nenhuma       Private Dwelling        #2 fuel oil       Petroleum
# 4          Nenhuma                Unknown   unknown material           Other
# ...            ...                    ...                ...             ...
# 168047     Nenhuma     Commercial Vehicle             diesel       Petroleum
# 168048     Nenhuma                Unknown  unknown petroleum       Petroleum
# 168049     Nenhuma  Commercial/Industrial        #2 fuel oil       Petroleum
# 168050     Nenhuma  Commercial/Industrial  unknown petroleum       Petroleum
# 168051  EAST RIVER                Unknown  unknown petroleum       Petroleum
#
#         Quantity         Units  Recovered Data_Derrame Data_Relatada  \
# 0            0.0        Pounds        0.0   2004-08-21    2004-08-21
# 1            0.0  Desconhecida        0.0   2004-08-21    2004-08-21
# 2            1.0       Gallons        0.0   2002-08-02    2002-08-02
# 3           75.0       Gallons        0.0   2004-01-11    2004-01-11
# 4            0.0       Gallons        0.0   2001-07-23    2001-07-23
# ...          ...           ...        ...          ...           ...
# 168047      20.0       Gallons        0.0   1999-07-06    1999-07-06
# 168048       0.0       Gallons        0.0   2003-07-28    2003-07-28
# 168049     200.0       Gallons        0.0   1993-03-02    1993-03-02
# 168050       0.0  Desconhecida        0.0   1990-01-05    1990-01-05
# 168051       0.0       Gallons        0.0   2001-06-13    2001-06-13
#
#           Data_Fim
# 0       2004-09-17
# 1       2004-09-17
# 2       2002-10-28
# 3       2004-08-25
# 4       2001-08-01
# ...            ...
# 168047  2009-03-03
# 168048  2014-01-08
# 168049  2003-02-10
# 168050  1990-01-05
# 168051  2013-05-07
#
# [168052 rows x 18 columns]

# %%
replaced_projeto_spill7 = replaced_projeto_spill6.withColumn("Data_Derrame", to_date(col("Data_Derrame"), "yyyy-MM-dd")) \
                                               .withColumn("Data_Relatada", to_date(col("Data_Relatada"), "yyyy-MM-dd")) \
                                                .withColumn("Data_Fim", to_date(col("Data_Fim"), "yyyy-MM-dd"))

replaced_projeto_spill8 = replaced_projeto_spill7.withColumn('Ano', (split(replaced_projeto_spill7['Data_Derrame'], '-').getItem(0)).cast(IntegerType()))
replaced_projeto_spill8.show()
# Out:
# +------------+---------------------+--------------------+-------------+--------+---------+----------+-------------------+----------+--------------------+------------------+---------------+--------+------------+---------+------------+-------------+----------+----+
# |Spill Number|Program Facility Name|            Street 1|     Locality|  Contry|SWIS Code|DEC Region|Contributing Factor| Waterbody|              Source|     Material Name|Material Family|Quantity|       Units|Recovered|Data_Derrame|Data_Relatada|  Data_Fim| Ano|
# +------------+---------------------+--------------------+-------------+--------+---------+----------+-------------------+----------+--------------------+------------------+---------------+--------+------------+---------+------------+-------------+----------+----+
# |    0405586 |   BOWRY BAY      ...|  WATER POLL CONTROL|       QUEENS|  Queens|     4101|         2|              Other|EAST RIVER|             Unknown|        raw sewage|          Other|     0.0|      Pounds|      0.0|  2004-08-21|   2004-08-21|2004-09-17|2004|
# |    0405586 |   BOWRY BAY      ...|  WATER POLL CONTROL|       QUEENS|  Queens|     4101|         2|              Other|EAST RIVER|             Unknown|        raw sewage|          Other|     0.0|Desconhecida|      0.0|  2004-08-21|   2004-08-21|2004-09-17|2004|
# |    0204667 |   POLE 16091     ...| GRACE AVE/BURKE AVE|        BRONX|   Bronx|      301|         2|  Equipment Failure|   Nenhuma|Commercial/Indust...|   transformer oil|      Petroleum|     1.0|     Gallons|      0.0|  2002-08-02|   2002-08-02|2002-10-28|2002|
# |    0311484 |   PRIVATE RESIDEN...|  6568 GLEN HAVEN RD|        SCOTT|Cortland|     1238|         7|  Equipment Failure|   Nenhuma|    Private Dwelling|       #2 fuel oil|      Petroleum|    75.0|     Gallons|      0.0|  2004-01-11|   2004-01-11|2004-08-25|2004|
# |    0104307 |  149TH RD        ...|183RD ST, 149TH A...|       QUEENS|  Queens|     4101|         2|    Abandoned Drums|   Nenhuma|             Unknown|  unknown material|          Other|     0.0|     Gallons|      0.0|  2001-07-23|   2001-07-23|2001-08-01|2001|
# |    0160046 |  ABANDONED DRUMS ...|BAKER SCHOOL HOUS...|        SOLON|Cortland|     1200|         7|    Abandoned Drums|   Nenhuma|             Unknown|  unknown material|          Other|     0.0|     Gallons|      0.0|  2001-11-23|   2001-11-23|2002-05-14|2001|
# |    9606869 |  AMSTERDAM AVE   ...|   WEST 79 TH STREET|          NYC|New York|     3101|         2|   Traffic Accident|   Nenhuma|  Commercial Vehicle|        antifreeze|          Other|     2.0|     Gallons|      2.0|  1996-08-28|   1996-08-28|1996-08-29|1996|
# |    0109039 |  APT BUILDING    ...|      94-06  34TH RD|       QUEENS|  Queens|     4101|         2|  Equipment Failure|   Nenhuma|          Tank Truck|       #2 fuel oil|      Petroleum|     5.0|     Gallons|      5.0|  2001-12-11|   2001-12-11|2001-12-21|2001|
# |    0312848 |  BROOKLYN TECH HI...| 29 FORT GREEN PLACE|     BROOKLYN|   Kings|     2401|         2|        Human Error|   Nenhuma|Institutional, Ed...|       #6 fuel oil|      Petroleum|    10.0|     Gallons|      0.0|  2004-02-20|   2004-02-20|2004-02-27|2004|
# |    0260048 |  CRAINS MILL ROAD...|    CRAINS MILL ROAD|      TRUXTON|Cortland|     1244|         7|         Deliberate|   Nenhuma|             Unknown|  unknown material|          Other|     0.0|     Gallons|      0.0|  2002-10-16|   2002-10-16|2002-10-20|2002|
# |    0405793 |  MANHOLE #58430  ...| W 59TH ST / 12TH AV|    MANHATTAN|New York|     3101|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     1.0|Desconhecida|      0.0|  2004-08-26|   2004-08-26|2006-10-23|2004|
# |    0405793 |  MANHOLE #58430  ...| W 59TH ST / 12TH AV|    MANHATTAN|New York|     3101|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     1.0|      Pounds|      0.0|  2004-08-26|   2004-08-26|2006-10-23|2004|
# |    0313032 |  MANHOLE #6014   ...|156-170 WEST 42ND...|    MANHATTAN|New York|     3101|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     2.0|     Gallons|      0.0|  2004-02-26|   2004-02-26|2004-07-15|2004|
# |    9814599 |  MANHOLE 2981    ...|CLASSON AVE & FUL...|     BROOKLYN|   Kings|     2401|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     4.0|     Gallons|      0.0|  1999-03-08|   1999-03-08|1999-03-22|1999|
# |    0401659 |  MANHOLE 4467    ...|GRAND ARMY PLAZA/...|     BROOKLYN|   Kings|     2401|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     1.0|     Gallons|      0.0|  2004-05-15|   2004-05-15|2004-09-14|2004|
# |    0011768 |  MANHOLE 829     ...|WILLIAMSBURG PL &...|NEW YORK CITY|   Kings|     2401|         2|            Unknown|   Nenhuma|             Unknown| unknown petroleum|      Petroleum|     1.0|     Gallons|      0.0|  2001-01-31|   2001-01-31|2001-06-05|2001|
# |    0208773 |  MH 17516        ...|LOCUST AV/E 140TH ST|        BRONX|   Bronx|      301|         2|            Unknown|   Nenhuma|             Unknown|  unknown material|          Other|     1.0|     Gallons|      0.0|  2002-11-23|   2002-11-24|2002-11-27|2002|
# |    0260008 |  MOBIL OIL COMPAN...| 452 GRANT BOULEVARD|     SYRACUSE|Onondaga|     3415|         7|  Equipment Failure|   Nenhuma|Gasoline Station ...|          gasoline|      Petroleum|     3.0|     Gallons|      3.0|  2002-04-19|   2002-04-19|2002-04-24|2002|
# |    9601810 |  MORGAN RD       ...|BWTN RT31 & WETZE...|    LIVERPOOL|Onondaga|     3400|         7|            Unknown|   Nenhuma|             Unknown|waste oil/used oil|      Petroleum|     0.0|     Gallons|      0.0|  1996-05-05|   1996-05-06|1996-07-30|1996|
# |    0203407 |  MR. PRASAUD     ...|     317 WOODBINE ST|     BROOKLYN|   Kings|     2401|         2|  Equipment Failure|   Nenhuma|  Commercial Vehicle|       #2 fuel oil|      Petroleum|     3.0|     Gallons|      0.0|  2002-07-01|   2002-07-01|2003-12-15|2002|
# +------------+---------------------+--------------------+-------------+--------+---------+----------+-------------------+----------+--------------------+------------------+---------------+--------+------------+---------+------------+-------------+----------+----+
# only showing top 20 rows

# %%
replaced_projeto_spill8.printSchema()
# Out:
# root
#  |-- Spill Number: string (nullable = true)
#  |-- Program Facility Name: string (nullable = true)
#  |-- Street 1: string (nullable = true)
#  |-- Locality: string (nullable = true)
#  |-- Contry: string (nullable = true)
#  |-- SWIS Code: integer (nullable = true)
#  |-- DEC Region: integer (nullable = true)
#  |-- Contributing Factor: string (nullable = true)
#  |-- Waterbody: string (nullable = true)
#  |-- Source: string (nullable = true)
#  |-- Material Name: string (nullable = true)
#  |-- Material Family: string (nullable = true)
#  |-- Quantity: float (nullable = true)
#  |-- Units: string (nullable = true)
#  |-- Recovered: float (nullable = true)
#  |-- Data_Derrame: date (nullable = true)
#  |-- Data_Relatada: date (nullable = true)
#  |-- Data_Fim: date (nullable = true)
#  |-- Ano: integer (nullable = true)

# %%
replaced_projeto_spill9 = replaced_projeto_spill8 \
    .withColumnRenamed("Spill Number","Spill_Number") \
    .withColumnRenamed("Program Facility Name","Program_Facility_Name") \
    .withColumnRenamed("Street 1","Street") \
    .withColumnRenamed("SWIS Code","SWIS_Code") \
    .withColumnRenamed("DEC Region","DEC_Region")\
    .withColumnRenamed("Contributing Factor","Contributing_Factor") \
    .withColumnRenamed("Material Name","Material_Name") \
    .withColumnRenamed("Material Family","Material_Family")

# %%
replaced_projeto_spill9.toPandas()
# Out:
#        Spill_Number      Program_Facility_Name                     Street  \
# 0          0405586     BOWRY BAY                       WATER POLL CONTROL
# 1          0405586     BOWRY BAY                       WATER POLL CONTROL
# 2          0204667     POLE 16091                     GRACE AVE/BURKE AVE
# 3          0311484     PRIVATE RESIDENCE               6568 GLEN HAVEN RD
# 4          0104307    149TH RD                  183RD ST, 149TH AV& 149RD
# ...             ...                        ...                        ...
# 168047     9904003                      `-NYCT         5TH AND WEST 50 ST
# 168048     0304463                      `-NYCT       35TH ST AND 11TH AVE
# 168049     9213322             `-NYCT / 146 ST              721 LENOX AVE
# 168050     8909580      `-NYCT BUS DEPOT - S I  CASTLETON AVE @ RECTOR ST
# 168051     0102768                `-RAVENSWOOD            3854 VERON BLVD
#
#                 Locality    Contry  SWIS_Code  DEC_Region Contributing_Factor  \
# 0                 QUEENS    Queens       4101           2               Other
# 1                 QUEENS    Queens       4101           2               Other
# 2                  BRONX     Bronx        301           2   Equipment Failure
# 3                  SCOTT  Cortland       1238           7   Equipment Failure
# 4                 QUEENS    Queens       4101           2     Abandoned Drums
# ...                  ...       ...        ...         ...                 ...
# 168047         MANHATTAN  New York       3101           2        Housekeeping
# 168048         MANHATTAN  New York       3101           2             Unknown
# 168049         MANHATTAN  New York       3101           2       Tank Overfill
# 168050     STATEN ISLAND  Richmond       4301           2     Abandoned Drums
# 168051  LONG ISLAND CITY    Queens       4101           2             Unknown
#
#          Waterbody                 Source      Material_Name Material_Family  \
# 0       EAST RIVER                Unknown         raw sewage           Other
# 1       EAST RIVER                Unknown         raw sewage           Other
# 2          Nenhuma  Commercial/Industrial    transformer oil       Petroleum
# 3          Nenhuma       Private Dwelling        #2 fuel oil       Petroleum
# 4          Nenhuma                Unknown   unknown material           Other
# ...            ...                    ...                ...             ...
# 168047     Nenhuma     Commercial Vehicle             diesel       Petroleum
# 168048     Nenhuma                Unknown  unknown petroleum       Petroleum
# 168049     Nenhuma  Commercial/Industrial        #2 fuel oil       Petroleum
# 168050     Nenhuma  Commercial/Industrial  unknown petroleum       Petroleum
# 168051  EAST RIVER                Unknown  unknown petroleum       Petroleum
#
#         Quantity         Units  Recovered Data_Derrame Data_Relatada  \
# 0            0.0        Pounds        0.0   2004-08-21    2004-08-21
# 1            0.0  Desconhecida        0.0   2004-08-21    2004-08-21
# 2            1.0       Gallons        0.0   2002-08-02    2002-08-02
# 3           75.0       Gallons        0.0   2004-01-11    2004-01-11
# 4            0.0       Gallons        0.0   2001-07-23    2001-07-23
# ...          ...           ...        ...          ...           ...
# 168047      20.0       Gallons        0.0   1999-07-06    1999-07-06
# 168048       0.0       Gallons        0.0   2003-07-28    2003-07-28
# 168049     200.0       Gallons        0.0   1993-03-02    1993-03-02
# 168050       0.0  Desconhecida        0.0   1990-01-05    1990-01-05
# 168051       0.0       Gallons        0.0   2001-06-13    2001-06-13
#
#           Data_Fim     Ano
# 0       2004-09-17  2004.0
# 1       2004-09-17  2004.0
# 2       2002-10-28  2002.0
# 3       2004-08-25  2004.0
# 4       2001-08-01  2001.0
# ...            ...     ...
# 168047  2009-03-03  1999.0
# 168048  2014-01-08  2003.0
# 168049  2003-02-10  1993.0
# 168050  1990-01-05  1990.0
# 168051  2013-05-07  2001.0
#
# [168052 rows x 19 columns]

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS Projeto.Tabela_Petroleo
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE Projeto.Tabela_Petroleo (
        Spill_Number VARCHAR(50),
        Program_Facility_Name VARCHAR(500), 
        Street VARCHAR(500),
        Locality VARCHAR(50),
        Contry VARCHAR(50),
        SWIS_Code int,
        DEC_Region int,
        Contributing_Factor VARCHAR(500),
        Waterbody VARCHAR(50),
        Source VARCHAR(50),
        Material_Name VARCHAR(500),
        Material_Family VARCHAR(500),
        Quantity float,
        Units VARCHAR(100),
        Recovered float,
        Data_Derrame date,
        Data_Relatada date,
        Data_Fim date

    )
       USING DELTA
   
   PARTITIONED BY (
        Ano INT

    )
    LOCATION 'hdfs://hdfs-nn:9000/TrabalhoPL/silver/Projeto.db/Tabela_Petroleo'
    """
)
# Out:
# DataFrame[]

# %%
#write df to hive deltalake_table
replaced_projeto_spill9 \
    .select("Spill_Number","Program_Facility_Name","Street","Locality","Contry","SWIS_Code",
            "DEC_Region","Contributing_Factor","Waterbody", "Source", "Material_Name", "Material_Family", 
            "Quantity", "Units", "Recovered", "Data_Derrame", "Data_Relatada", "Data_Fim", "Ano") \
    .write \
    .mode("overwrite") \
    .partitionBy("Ano") \
    .format("delta") \
    .save("hdfs://hdfs-nn:9000/TrabalhoPL/silver/Projeto.db/Tabela_Petroleo")
from pyspark.sql.types import *

# %%
spark.sql("USE Projeto")
spark.sql("SHOW tables").show()
# Out:
# +---------+-----------------+-----------+
# |namespace|        tableName|isTemporary|
# +---------+-----------------+-----------+
# |  projeto|             agua|      false|
# |  projeto|      tabela_agua|      false|
# |  projeto|        tabela_ar|      false|
# |  projeto|  tabela_petroleo|      false|
# |  projeto|tabela_reciclagem|      false|
# +---------+-----------------+-----------+

# %%
spark.table("Projeto.Tabela_Petroleo").show()
# Out:
# +------------+---------------------+--------------------+----------------+--------+---------+----------+-------------------+--------------------+--------------------+--------------------+------------------+--------+------------+---------+------------+-------------+----------+----+
# |Spill_Number|Program_Facility_Name|              Street|        Locality|  Contry|SWIS_Code|DEC_Region|Contributing_Factor|           Waterbody|              Source|       Material_Name|   Material_Family|Quantity|       Units|Recovered|Data_Derrame|Data_Relatada|  Data_Fim| Ano|
# +------------+---------------------+--------------------+----------------+--------+---------+----------+-------------------+--------------------+--------------------+--------------------+------------------+--------+------------+---------+------------+-------------+----------+----+
# |    9506819 | 1 BEEKMAN PLACE  ...|     1 BEEKMAN PLACE|       MANHATTAN|New York|     3101|         2|            Unknown|             Nenhuma|Institutional, Ed...|            gasoline|         Petroleum|     0.0|      Pounds|      0.0|  1995-09-05|   1995-09-05|2000-12-06|1995|
# |    9508616 |    1 EDGEWATER PLAZA|   1 EDGEWATER PLAZA|   STATEN ISLAND|Richmond|     4301|         2|            Unknown|           NY HARBOR|             Unknown|    unknown material|             Other|     0.0|     Gallons|      0.0|  1995-10-13|   1995-10-13|2003-02-13|1995|
# |    9511445 | 1 FERRY SLIP     ...|STATEN ISLAND FER...|   STATEN ISLAND|Richmond|     4301|         2|  Equipment Failure|UPPER NEW YORK HARBO|Institutional, Ed...|              diesel|         Petroleum|     0.0|     Gallons|      0.0|  1995-12-11|   1995-12-11|1995-12-11|1995|
# |    9509855 | 1 PROSPECT PARK W...|1 PROSPECT PARK WEST|        BROOKLYN|   Kings|     2401|         2|       Tank Failure|             Nenhuma|    Private Dwelling|         #2 fuel oil|         Petroleum|     0.0|     Gallons|      0.0|  1995-11-04|   1995-11-08|1996-09-23|1995|
# |    9503012 | 1 RICHMOND TERRAC...|  1 RICHMOND TERRACE|   STATEN ISLAND|Richmond|     4301|         2|        Human Error|          EAST RIVER|              Vessel|         #2 fuel oil|         Petroleum|     1.0|     Gallons|      0.0|  1995-06-09|   1995-06-09|1995-06-09|1995|
# |    9510231 | 1 SICKLES ST     ...|        1 SICKLES ST|       MANHATTAN|New York|     3101|         2|            Unknown|             Nenhuma|             Unknown|         2-propanone|Hazardous Material|     0.0|     Gallons|      0.0|  1995-11-15|   1995-11-15|1995-11-20|1995|
# |    9505632 | 1 WILSON AVENUE  ...|     1 WILSON AVENUE|        RICHMOND|Richmond|     4301|         2|  Equipment Failure|             Nenhuma|    Private Dwelling|         #2 fuel oil|         Petroleum|     1.0|     Gallons|      1.0|  1995-08-07|   1995-08-07|1998-04-30|1995|
# |    9505195 | 1-11 HUDSON AVENU...|  1-11 HUDSON AVENUE|        BROOKLYN|   Kings|     2401|         2|            Unknown|          EAST RIVER|             Unknown|  waste oil/used oil|         Petroleum|     0.0|     Gallons|      0.0|  1995-07-28|   1995-07-28|2004-01-20|1995|
# |    9504968 | 1-11 HUDSON AVENU...|  1-11 HUDSON AVENUE|        BROOKLYN|   Kings|     2401|         2|         Deliberate|          EAST RIVER|             Unknown|   unknown petroleum|         Petroleum|     5.0|     Gallons|      0.0|  1995-07-24|   1995-07-24|2004-01-20|1995|
# |    9501384 | 1-1102 JAMAICA AV...|1-1102 JAMAICA AV...|   RICHMOND HILL|  Queens|     4101|         2|      Tank Overfill|             Nenhuma|          Tank Truck|         #2 fuel oil|         Petroleum|     2.0|     Gallons|      0.0|  1995-05-03|   1995-05-02|1995-05-03|1995|
# |    9501744 | 1-5 7TH AVE SOUTH...|   1-5 7TH AVE SOUTH|        NEW YORK|New York|     3101|         2|  Equipment Failure|             Nenhuma|Gasoline Station ...|            gasoline|         Petroleum|     0.0|     Gallons|      0.0|  1995-05-10|   1995-05-11|2013-09-30|1995|
# |    9502878 | 10 CROSBY STREET ...|    10 CROSBY STREET|       MANHATTAN|New York|     3101|         2|  Equipment Failure|             Nenhuma|Commercial/Indust...|         #4 fuel oil|         Petroleum|    50.0|     Gallons|      0.0|  1995-06-07|   1995-06-07|2003-02-24|1995|
# |    9506878 | 10-26 53RD AVENUE...|   10-26 53RD AVENUE|LONG ISLAND CITY|  Queens|     4101|         2|            Unknown|             Nenhuma|             Unknown|                lead|Hazardous Material|     0.0|      Pounds|      0.0|  1995-09-06|   1995-09-06|1997-10-16|1995|
# |    9506878 | 10-26 53RD AVENUE...|   10-26 53RD AVENUE|LONG ISLAND CITY|  Queens|     4101|         2|            Unknown|             Nenhuma|             Unknown|   unknown petroleum|         Petroleum|     0.0|     Gallons|      0.0|  1995-09-06|   1995-09-06|1997-10-16|1995|
# |    9415189 | 100 EAST 18TH ST ...|    100 EAST 18TH ST|        BROOKLYN|   Kings|     2401|         2|      Tank Overfill|             Nenhuma|    Private Dwelling|         #6 fuel oil|         Petroleum|     5.0|     Gallons|      0.0|  1995-02-20|   1995-02-20|2004-01-26|1995|
# |    9502049 | 100 KRATZ AVE    ...|       100 KRATZ AVE|        SYRACUSE|Onondaga|     3415|         7|         Deliberate|             Nenhuma|Commercial/Indust...|       white caustic|Hazardous Material|     0.0|Desconhecida|      0.0|  1995-05-18|   1995-05-18|1995-05-18|1995|
# |    9509770 | 100 SUTTON ST    ...|       100 SUTTON ST|        BROOKLYN|   Kings|     2401|         2|         Deliberate|             Nenhuma|Commercial/Indust...|unknown hazardous...|Hazardous Material|     0.0|     Gallons|      0.0|  1995-11-07|   1995-11-07|1995-11-08|1995|
# |    9511396 | 100 WEST 73RD ST ...|    100 WEST 73RD ST|        NEW YORK|New York|     3101|         2|  Equipment Failure|             Nenhuma|             Unknown|         #2 fuel oil|         Petroleum|    20.0|     Gallons|      0.0|  1995-12-09|   1995-12-09|1998-11-10|1995|
# |    9506634 | 100-50 202ND STRE...| 100-50 202ND STREET|          HOLLIS|  Queens|     4101|         2|  Equipment Failure|             Nenhuma|    Private Dwelling|         #2 fuel oil|         Petroleum|     2.0|     Gallons|      2.0|  1995-08-29|   1995-08-30|1995-08-30|1995|
# |    9414305 | 100-52  205TH PLA...|  100-52 205TH PLACE|          HOLLIS|  Queens|     4101|         2|  Equipment Failure|             Nenhuma|    Private Dwelling|         #2 fuel oil|         Petroleum|     2.0|     Gallons|      2.0|  1995-01-29|   1995-01-29|1995-01-30|1995|
# +------------+---------------------+--------------------+----------------+--------+---------+----------+-------------------+--------------------+--------------------+--------------------+------------------+--------+------------+---------+------------+-------------+----------+----+
# only showing top 20 rows
