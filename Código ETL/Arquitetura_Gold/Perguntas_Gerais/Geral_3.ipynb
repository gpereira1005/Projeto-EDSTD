# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/TrabalhoPL'

builder = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
spark.sql(
    """
    drop table if exists Projeto_gold.Geral_3
    """
)
# Out:
# DataFrame[]

# %%
ar = spark.table("Projeto_Gold.Tabela_Ar")
ar = ar.withColumnRenamed("Media","Media_Ozono")
reci = spark.table("Projeto_Gold.Tabela_Reciclagem_3")
reci = reci.withColumnRenamed("Media","Media_Reciclagem")
ar.show()
reci.show()
# Out:
# +-------------+--------------------+------------------+
# |   Localidade|                Name|       Media_Ozono|
# +-------------+--------------------+------------------+
# |    Manhattan|PM2.5-Attributabl...|16.242763671008024|
# |       Queens|          Ozone (O3)| 32.00909091005422|
# |        Bronx|PM2.5-Attributabl...|22.291722238063812|
# |       Queens|PM2.5-Attributabl...|16.150511958382346|
# |        Bronx|Nitrogen Dioxide ...|20.535798615879482|
# |        Bronx|Boiler Emissions-...|           1.28125|
# |New York City|Boiler Emissions-...| 4.799999952316284|
# |       Queens|Boiler Emissions-...|16.136363809758965|
# |     Brooklyn|Sulfur Dioxide (SO2)|1.8124999977739118|
# |    Manhattan|Fine Particulate ...|10.722705766497326|
# |        Bronx|Boiler Emissions-...| 9.918750114738941|
# |        Bronx|          Ozone (O3)|30.706354207462734|
# |New York City|O3-Attributable C...| 4.850000023841858|
# |        Bronx|O3-Attributable A...|125.53125062584877|
# |New York City|O3-Attributable A...|14.000000178813934|
# |        Bronx|O3-Attributable C...| 4.725000008940697|
# |        Bronx|PM2.5-Attributabl...|128.66283163428307|
# |    Manhattan|Boiler Emissions-...| 4.627272706140172|
# |     Brooklyn|PM2.5-Attributabl...| 48.10924752553304|
# |       Queens|PM2.5-Attributabl...| 41.02150620113719|
# +-------------+--------------------+------------------+
# only showing top 20 rows
#
# +-------------+---------------------+
# |         Zone|Media_Reciclado_Comum|
# +-------------+---------------------+
# |   Brooklyn  |    45.35925924336469|
# |     Queens  |   50.135267754395805|
# |Staten Island|    55.53194446033902|
# |    Manhattan|    46.33038197623359|
# |        Bronx|   40.196875029140045|
# +-------------+---------------------+

# %%
geral = reci.join(ar, (reci.Zone == ar.Localidade),"inner")

# %%
geral = geral.drop(ar.Localidade)

# %%
geral.toPandas()
# Out:
#              Zone  Media_Reciclado_Comum  \
# 0       Manhattan              46.330382
# 1           Bronx              40.196875
# 2           Bronx              40.196875
# 3           Bronx              40.196875
# 4       Manhattan              46.330382
# 5           Bronx              40.196875
# 6           Bronx              40.196875
# 7           Bronx              40.196875
# 8           Bronx              40.196875
# 9           Bronx              40.196875
# 10      Manhattan              46.330382
# 11  Staten Island              55.531944
# 12  Staten Island              55.531944
# 13  Staten Island              55.531944
# 14      Manhattan              46.330382
# 15      Manhattan              46.330382
# 16  Staten Island              55.531944
# 17  Staten Island              55.531944
# 18  Staten Island              55.531944
# 19          Bronx              40.196875
# 20  Staten Island              55.531944
# 21      Manhattan              46.330382
# 22  Staten Island              55.531944
# 23      Manhattan              46.330382
# 24      Manhattan              46.330382
# 25      Manhattan              46.330382
# 26  Staten Island              55.531944
# 27  Staten Island              55.531944
# 28          Bronx              40.196875
# 29      Manhattan              46.330382
# 30      Manhattan              46.330382
# 31      Manhattan              46.330382
# 32  Staten Island              55.531944
# 33          Bronx              40.196875
# 34      Manhattan              46.330382
# 35          Bronx              40.196875
# 36          Bronx              40.196875
# 37  Staten Island              55.531944
# 38      Manhattan              46.330382
# 39  Staten Island              55.531944
# 40          Bronx              40.196875
# 41  Staten Island              55.531944
# 42      Manhattan              46.330382
# 43          Bronx              40.196875
# 44  Staten Island              55.531944
# 45      Manhattan              46.330382
# 46          Bronx              40.196875
# 47  Staten Island              55.531944
# 48  Staten Island              55.531944
# 49  Staten Island              55.531944
# 50  Staten Island              55.531944
# 51      Manhattan              46.330382
# 52      Manhattan              46.330382
# 53          Bronx              40.196875
# 54          Bronx              40.196875
# 55          Bronx              40.196875
# 56      Manhattan              46.330382
#
#                                                  Name  Media_Ozono
# 0   PM2.5-Attributable Cardiovascular Hospitalizat...    16.242764
# 1   PM2.5-Attributable Cardiovascular Hospitalizat...    22.291722
# 2                              Nitrogen Dioxide (NO2)    20.535799
# 3             Boiler Emissions- Total PM2.5 Emissions     1.281250
# 4                     Fine Particulate Matter (PM2.5)    10.722706
# 5               Boiler Emissions- Total SO2 Emissions     9.918750
# 6                                          Ozone (O3)    30.706354
# 7   O3-Attributable Asthma Emergency Department Vi...   125.531251
# 8      O3-Attributable Cardiac and Respiratory Deaths     4.725000
# 9   PM2.5-Attributable Asthma Emergency Department...   128.662832
# 10            Boiler Emissions- Total PM2.5 Emissions     4.627273
# 11                                         Ozone (O3)    31.020000
# 12  PM2.5-Attributable Respiratory Hospitalization...    15.430053
# 13     O3-Attributable Cardiac and Respiratory Deaths     7.585000
# 14                               Sulfur Dioxide (SO2)     4.307407
# 15              Boiler Emissions- Total SO2 Emissions    37.454546
# 16                          PM2.5-Attributable Deaths    54.512693
# 17  PM2.5-Attributable Asthma Emergency Department...    39.881479
# 18                               Sulfur Dioxide (SO2)     0.981094
# 19                          PM2.5-Attributable Deaths    57.674798
# 20            Boiler Emissions- Total PM2.5 Emissions     0.000000
# 21                                         Ozone (O3)    27.039630
# 22              Boiler Emissions- Total NOx Emissions     2.850000
# 23              Boiler Emissions- Total NOx Emissions   154.450001
# 24                             Nitrogen Dioxide (NO2)    26.769753
# 25            O3-Attributable Asthma Hospitalizations    10.948864
# 26                             Nitrogen Dioxide (NO2)    15.135000
# 27            O3-Attributable Asthma Hospitalizations     9.297500
# 28  PM2.5-Attributable Respiratory Hospitalization...    23.157002
# 29  PM2.5-Attributable Respiratory Hospitalization...    13.075016
# 30  O3-Attributable Asthma Emergency Department Vi...    78.334091
# 31     O3-Attributable Cardiac and Respiratory Deaths     3.881818
# 32              Boiler Emissions- Total SO2 Emissions     0.080000
# 33                    Fine Particulate Matter (PM2.5)     9.587593
# 34                          PM2.5-Attributable Deaths    49.241504
# 35                               Sulfur Dioxide (SO2)     3.463281
# 36              Boiler Emissions- Total NOx Emissions    47.068750
# 37                    Fine Particulate Matter (PM2.5)     8.514201
# 38  PM2.5-Attributable Asthma Emergency Department...    82.643646
# 39  PM2.5-Attributable Cardiovascular Hospitalizat...    17.983104
# 40            O3-Attributable Asthma Hospitalizations    24.251562
# 41  O3-Attributable Asthma Emergency Department Vi...    50.992500
# 42  Air Toxics Concentrations- Average Formaldehyd...     3.188235
# 43  Air Toxics Concentrations- Average Benzene Con...     1.862797
# 44  Air Toxics Concentrations- Average Formaldehyd...     1.961538
# 45  Air Toxics Concentrations- Average Benzene Con...     3.166852
# 46  Air Toxics Concentrations- Average Formaldehyd...     2.467857
# 47  Air Toxics Concentrations- Average Benzene Con...     1.308336
# 48     Traffic Density- Annual Vehicle Miles Traveled    10.133333
# 49  Traffic Density- Annual Vehicle Miles Traveled...     9.562500
# 50  Traffic Density- Annual Vehicle Miles Traveled...     0.520000
# 51  Traffic Density- Annual Vehicle Miles Traveled...     2.624444
# 52  Traffic Density- Annual Vehicle Miles Traveled...    47.210869
# 53  Traffic Density- Annual Vehicle Miles Traveled...    24.425000
# 54  Traffic Density- Annual Vehicle Miles Traveled...     2.200000
# 55     Traffic Density- Annual Vehicle Miles Traveled    26.843590
# 56     Traffic Density- Annual Vehicle Miles Traveled    50.368889

# %%
spark.sql("""
DROP TABLE IF EXISTS Projeto_gold.Geral_3
""")

spark.sql(
    """
    CREATE EXTERNAL TABLE Projeto_gold.Geral_3 (
        Zone VARCHAR(50), 
        Media_Reciclado_Comum DOUBLE, 
        Name VARCHAR(250), 
        Media_Ozono DOUBLE
    )
    USING DELTA
    LOCATION 'hdfs://hdfs-nn:9000/TrabalhoPL/gold/Projeto_gold.db/Geral_3'
    """
)
# Out:
# DataFrame[]

# %%
geral \
    .write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true")\
    .save("hdfs://hdfs-nn:9000/TrabalhoPL/gold/Projeto_gold.db/Geral_3")

# %%
spark.table("Projeto_gold.Geral_3").show()
# Out:
# +-------------+---------------------+--------------------+------------------+
# |         Zone|Media_Reciclado_Comum|                Name|       Media_Ozono|
# +-------------+---------------------+--------------------+------------------+
# |    Manhattan|    46.33038197623359|PM2.5-Attributabl...|16.242763671008024|
# |        Bronx|   40.196875029140045|PM2.5-Attributabl...|22.291722238063812|
# |        Bronx|   40.196875029140045|Nitrogen Dioxide ...|20.535798615879482|
# |        Bronx|   40.196875029140045|Boiler Emissions-...|           1.28125|
# |    Manhattan|    46.33038197623359|Fine Particulate ...|10.722705766497326|
# |        Bronx|   40.196875029140045|Boiler Emissions-...| 9.918750114738941|
# |        Bronx|   40.196875029140045|          Ozone (O3)|30.706354207462734|
# |        Bronx|   40.196875029140045|O3-Attributable A...|125.53125062584877|
# |        Bronx|   40.196875029140045|O3-Attributable C...| 4.725000008940697|
# |        Bronx|   40.196875029140045|PM2.5-Attributabl...|128.66283163428307|
# |    Manhattan|    46.33038197623359|Boiler Emissions-...| 4.627272706140172|
# |Staten Island|    55.53194446033902|          Ozone (O3)|31.019999901453655|
# |Staten Island|    55.53194446033902|PM2.5-Attributabl...|15.430052518844604|
# |Staten Island|    55.53194446033902|O3-Attributable C...| 7.584999942779541|
# |    Manhattan|    46.33038197623359|Sulfur Dioxide (SO2)| 4.307407417507084|
# |    Manhattan|    46.33038197623359|Boiler Emissions-...|37.454545671289615|
# |Staten Island|    55.53194446033902|PM2.5-Attributabl...|54.512692832946776|
# |Staten Island|    55.53194446033902|PM2.5-Attributabl...| 39.88147931098938|
# |Staten Island|    55.53194446033902|Sulfur Dioxide (SO2)|0.9810937514994293|
# |        Bronx|   40.196875029140045|PM2.5-Attributabl...|57.674797892570496|
# +-------------+---------------------+--------------------+------------------+
# only showing top 20 rows

# %%
spark.sql("""
GENERATE symlink_format_manifest FOR TABLE delta.`hdfs://hdfs-nn:9000/TrabalhoPL/gold/Projeto_gold.db/Geral_3/`
""").show()
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("""
DROP TABLE IF EXISTS Projeto_gold.Geral_Presto_3
""").show()

spark.sql("""
    CREATE EXTERNAL TABLE IF NOT EXISTS Projeto_gold.Geral_Presto_3 (
        Zone VARCHAR(50), 
        Media_Reciclado_Comum DOUBLE, 
        Name VARCHAR(250), 
        Media_Ozono DOUBLE
    )
    ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
    STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
    OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
    LOCATION 'hdfs://hdfs-nn:9000/TrabalhoPL/gold/Projeto_gold.db/Geral_3/_symlink_format_manifest/'
    """).show()
# Out:
# ++
# ||
# ++
# ++
#
# ++
# ||
# ++
# ++

# %%
# Out:
# DataFrame[]
